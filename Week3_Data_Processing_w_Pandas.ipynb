# %% [markdown]
# # Data Processing with Pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df.shape
# Out:
# (3193, 100)

# %%
df.SUMLEV.value_counts()
# Out:
# 50    3142
# 40      51
# Name: SUMLEV, dtype: int64

# %%
(df[df.SUMLEV==50]
 .set_index(['STNAME','CTYNAME'])
 .rename(columns={'ESTIMATESBASE2010':'Estimates Base 2010'}))
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County         50       3         6      1       1
#         Baldwin County         50       3         6      1       3
#         Barbour County         50       3         6      1       5
#         Bibb County            50       3         6      1       7
#         Blount County          50       3         6      1       9
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County      50       4         8     56      37
#         Teton County           50       4         8     56      39
#         Uinta County           50       4         8     56      41
#         Washakie County        50       4         8     56      43
#         Weston County          50       4         8     56      45
#
#                            CENSUS2010POP  Estimates Base 2010  \
# STNAME  CTYNAME
# Alabama Autauga County             54571                54571
# ...

# %%
import timeit

# %%
def first_approach():
    global df
    return (df.where(df.SUMLEV==50)
            .dropna()
            .set_index(['STNAME','CTYNAME'])
            .rename(columns={'ESTIMATESBASE2010':'Estimates Base 2010'}))
df = pd.read_csv('census.csv')
timeit.timeit(first_approach, number=10)
# Out:
# 0.35297429999991436

# %%
def second_approach():
    global df
    new_df = df[df.SUMLEV==50]
    new_df.set_index(['STNAME','CTYNAME'], inplace=True)
    new_df.rename(columns={'ESTIMATESBASE2010':'Estimates Base 2010'}, inplace=True)
    return new_df

df = pd.read_csv('census.csv')
timeit.timeit(second_approach, number=10)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# 0.07860330000039539

# %% [markdown]
# _Second approach is much faster._

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df.POPESTIMATE2010.min()
# Out:
# 83

# %%
df.POPESTIMATE2010.max()
# Out:
# 37334079

# %%
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    row['max'] = np.max(data)
    row['min'] = np.min(data)
    return row

df.apply(min_max, axis='columns')
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
rows=['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']

df.apply(lambda x: np.max(x[rows]), axis=1).head()
# Out:
# 0    4858979
# 1      55347
# 2     203709
# 3      27341
# 4      22861
# dtype: int64

# %%
def get_state_region(x):
    northeast = ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 
                 'Rhode Island','Vermont','New York','New Jersey','Pennsylvania']
    midwest = ['Illinois','Indiana','Michigan','Ohio','Wisconsin','Iowa',
               'Kansas','Minnesota','Missouri','Nebraska','North Dakota',
               'South Dakota']
    south = ['Delaware','Florida','Georgia','Maryland','North Carolina',
             'South Carolina','Virginia','District of Columbia','West Virginia',
             'Alabama','Kentucky','Mississippi','Tennessee','Arkansas',
             'Louisiana','Oklahoma','Texas']
    west = ['Arizona','Colorado','Idaho','Montana','Nevada','New Mexico','Utah',
            'Wyoming','Alaska','California','Hawaii','Oregon','Washington']
    
    if x in northeast:
        return "Northeast"
    elif x in midwest:
        return "Midwest"
    elif x in south:
        return "South"
    else:
        return "West"

# %%
df['state_region'] = df['STNAME'].apply(lambda x: get_state_region(x))
df[['STNAME','state_region']].head()
# Out:
#     STNAME state_region
# 0  Alabama        South
# 1  Alabama        South
# 2  Alabama        South
# 3  Alabama        South
# 4  Alabama        South

# %% [markdown]
# # Groupby

# %%
df = pd.read_csv('census.csv')

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df.set_index('SUMLEV').groupby(level=0).sum()
# Out:
#         REGION  DIVISION  STATE  COUNTY  CENSUS2010POP  ESTIMATESBASE2010  \
# SUMLEV
# 40         136       261   1477       0      308745538          308758105
# 50        8385     16315  95140  325426      308739316          308758105
#
#         POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# SUMLEV
# 40            309346863        311718857        314102623        316427395
# 50            309346863        311718857        314102623        316427395
#
#         ...  RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# SUMLEV  ...
# 40      ...         15.542590         32.726057         39.155152
# 50      ...      -5249.404228      -8105.847163      -4152.003444
#
#         RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  \
# SUMLEV
# 40             -4.130911         -1.871627   131.092446   160.350589
# 50          -7250.126632      -4348.933163 -2223.163388 -4776.708609
#
#         RNETMIG2013  RNETMIG2014  RNETMIG2015
# SUMLEV
# ...

# %% [markdown]
# ## Aggregation

# %%
df = pd.read_csv('listings.csv')
df.head(2)
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
#
#   last_scraped                               name  \
# 0   2016-09-07         Sunny Bungalow in the City
# 1   2016-09-07  Charming room in pet friendly apt
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
#
# ...

# %%
df.shape
# Out:
# (3585, 95)

# %%
df.groupby('cancellation_policy')['review_scores_value'].mean()
# Out:
# cancellation_policy
# flexible           9.237421
# moderate           9.307398
# strict             9.081441
# super_strict_30    8.537313
# Name: review_scores_value, dtype: float64

# %%
df.groupby('cancellation_policy').agg({'review_scores_value':np.mean, 'reviews_per_month':np.sum})
# Out:
#                      review_scores_value  reviews_per_month
# cancellation_policy
# flexible                        9.237421            1227.40
# moderate                        9.307398            1903.97
# strict                          9.081441            2420.52
# super_strict_30                 8.537313              23.81

# %%
df.groupby('cancellation_policy').agg({'review_scores_value':(np.mean, np.std),
                                       'reviews_per_month':np.mean})
# Out:
#                     review_scores_value           reviews_per_month
#                                    mean       std              mean
# cancellation_policy
# flexible                       9.237421  1.096271          1.829210
# moderate                       9.307398  0.859859          2.391922
# strict                         9.081441  1.040531          1.873467
# super_strict_30                8.537313  0.840785          0.340143

# %% [markdown]
# ## Transformation

# %%
df['mean_review_scores']=df.groupby('cancellation_policy')['review_scores_value'].transform(np.mean)

# %%
df[df.cancellation_policy=='super_strict_30'].sample(2)
# Out:
#            id                           listing_url       scrape_id  \
# 1972    54944    https://www.airbnb.com/rooms/54944  20160906204935
# 2025  2821825  https://www.airbnb.com/rooms/2821825  20160906204935
#
#      last_scraped                                 name  \
# 1972   2016-09-07  [1414] Renovated Beacon Hill Studio
# 2025   2016-09-07     [1852-2C]2BRs in Downtown Boston
#
#                                                 summary  \
# 1972  Private studio suite in historic brownstone in...
# 2025  This luxurious Boston property offers elegant ...
#
#                                                   space  \
# 1972  This second floor walk-up has a decorative fir...
# 2025  Residents can enjoy fantastic on-site amenitie...
#
#                                             description experiences_offered  \
# 1972  Private studio suite in historic brownstone in...                none
# 2025  This luxurious Boston property offers elegant ...                none
#
# ...

# %%
df['mean_diff'] = np.abs(df.review_scores_value - df.mean_review_scores)

# %%
df.sample(5)
# Out:
#             id                            listing_url       scrape_id  \
# 3334   9813223   https://www.airbnb.com/rooms/9813223  20160906204935
# 353    5212321   https://www.airbnb.com/rooms/5212321  20160906204935
# 2151  14110129  https://www.airbnb.com/rooms/14110129  20160906204935
# 1888   6778788   https://www.airbnb.com/rooms/6778788  20160906204935
# 2770   7106162   https://www.airbnb.com/rooms/7106162  20160906204935
#
#      last_scraped                                               name  \
# 3334   2016-09-07                Loaded studio steps to Comm/Harv Av
# 353    2016-09-07  Wonderful home Great Neighborhood mins from Bo...
# 2151   2016-09-07   wifi,clean,neat,A/C,locker,1 min to train,washer
# 1888   2016-09-07                       Renovated Beacon Hill Beauty
# 2770   2016-09-07                            Luxury Duplex Apartment
#
#                                                 summary  \
# 3334  Tiny hand crafted basement studio right near c...
# ...

# %% [markdown]
# ## Filtering

# %%
df.groupby('cancellation_policy').filter(lambda x: np.mean(x['review_scores_value'])>9.2).head(2)
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
#
#   last_scraped                               name  \
# 0   2016-09-07         Sunny Bungalow in the City
# 1   2016-09-07  Charming room in pet friendly apt
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
#
# ...

# %% [markdown]
# ## Applying

# %%
df=pd.read_csv("listings.csv")
df=df[['cancellation_policy','review_scores_value']]
df.head()
# Out:
#   cancellation_policy  review_scores_value
# 0            moderate                  NaN
# 1            moderate                  9.0
# 2            moderate                 10.0
# 3            moderate                 10.0
# 4            flexible                 10.0

# %%
df.shape
# Out:
# (3585, 2)

# %%
def calc_mean_review_scores(group):
    # group is a dataframe just of whatever we have grouped by, e.g. cancellation policy, so we can treat
    # this as the complete dataframe
    avg=np.nanmean(group["review_scores_value"])
    # now broadcast our formula and create a new column
    group["review_scores_mean"]=np.abs(avg-group["review_scores_value"])
    return group

# %%
df.groupby('cancellation_policy').apply(calc_mean_review_scores).head()
# Out:
#   cancellation_policy  review_scores_value  review_scores_mean
# 0            moderate                  NaN                 NaN
# 1            moderate                  9.0            0.307398
# 2            moderate                 10.0            0.692602
# 3            moderate                 10.0            0.692602
# 4            flexible                 10.0            0.762579

# %% [markdown]
# # Scales

# %%
df=pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 
                       'ok', 'ok', 'ok', 'poor', 'poor'],
               columns=["Grades"])
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
df.dtypes
# Out:
# Grades    object
# dtype: object

# %%
df["Grades"].astype("category").head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
my_categories=pd.CategoricalDtype(categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'], 
                           ordered=True)
# then we can just pass this to the astype() function
grades=df["Grades"].astype(my_categories)
grades.head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
df[df["Grades"]>"C"]
# Out:
#      Grades
# ok       C+
# ok       C-
# poor     D+
# poor      D

# %%
grades[grades>"C"]
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
df=pd.read_csv("census.csv")
df=df[df['SUMLEV']==50]
df=df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg(np.average)

df.head()
# Out:
# STNAME
# Alabama        71339.343284
# Alaska         24490.724138
# Arizona       426134.466667
# Arkansas       38878.906667
# California    642309.586207
# Name: CENSUS2010POP, dtype: float64

# %%
df
# Out:
# STNAME
# Alabama                  71339.343284
# Alaska                   24490.724138
# Arizona                 426134.466667
# Arkansas                 38878.906667
# California              642309.586207
# Colorado                 78581.187500
# Connecticut             446762.125000
# Delaware                299311.333333
# District of Columbia    601723.000000
# Florida                 280616.567164
# Georgia                  60928.635220
# Hawaii                  272060.200000
# Idaho                    35626.863636
# Illinois                125790.509804
# Indiana                  70476.108696
# Iowa                     30771.262626
# Kansas                   27172.552381
# Kentucky                 36161.391667
# Louisiana                70833.937500
# Maine                    83022.562500
# Maryland                240564.666667
# Massachusetts           467687.785714
# Michigan                119080.000000
# Minnesota                60964.655172
# ...

# %%
pd.cut(df,10)
# Out:
# STNAME
# Alabama                   (11706.087, 75333.413]
# Alaska                    (11706.087, 75333.413]
# Arizona                 (390320.176, 453317.529]
# Arkansas                  (11706.087, 75333.413]
# California              (579312.234, 642309.586]
# Colorado                 (75333.413, 138330.766]
# Connecticut             (390320.176, 453317.529]
# Delaware                (264325.471, 327322.823]
# District of Columbia    (579312.234, 642309.586]
# Florida                 (264325.471, 327322.823]
# Georgia                   (11706.087, 75333.413]
# Hawaii                  (264325.471, 327322.823]
# Idaho                     (11706.087, 75333.413]
# Illinois                 (75333.413, 138330.766]
# Indiana                   (11706.087, 75333.413]
# Iowa                      (11706.087, 75333.413]
# Kansas                    (11706.087, 75333.413]
# Kentucky                  (11706.087, 75333.413]
# Louisiana                 (11706.087, 75333.413]
# ...

# %% [markdown]
# # Pivot Table

# %%
df=pd.read_csv('cwurData.csv')
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
df2=df[['world_rank','institution']]
df2.head()
# Out:
#    world_rank                            institution
# 0           1                     Harvard University
# 1           2  Massachusetts Institute of Technology
# 2           3                    Stanford University
# 3           4                University of Cambridge
# 4           5     California Institute of Technology

# %%
def ranking(x):
    if x<101:
        return 'Fist Tier Top University'
    elif x<201:
        return 'Second Tier Top University'
    elif x<301:
        return 'Third Tier Top University'
    else:
        return 'Other Top University'

# %%
df['Rank_Level'] = df.world_rank.apply(ranking)

# %%
df
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
df['Rank_Level_2'] = df.world_rank.apply(lambda x: ranking(x))

# %%
df
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=np.mean).head()
# Out:
# Rank_Level  Fist Tier Top University  Other Top University  \
# country
# Argentina                        NaN             44.672857
# Australia                    47.9425             44.645750
# Austria                          NaN             44.864286
# Belgium                      51.8750             45.081000
# Brazil                           NaN             44.499706
#
# Rank_Level  Second Tier Top University  Third Tier Top University
# country
# Argentina                          NaN                        NaN
# Australia                      49.2425                  47.285000
# Austria                            NaN                  47.066667
# Belgium                        49.0840                  46.746667
# Brazil                         49.5650                        NaN

# %%
df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.mean, np.max]).head()
# Out:
#                                mean                       \
# Rank_Level Fist Tier Top University Other Top University
# country
# Argentina                       NaN            44.672857
# Australia                   47.9425            44.645750
# Austria                         NaN            44.864286
# Belgium                     51.8750            45.081000
# Brazil                          NaN            44.499706
#
#                                                                  \
# Rank_Level Second Tier Top University Third Tier Top University
# country
# Argentina                         NaN                       NaN
# Australia                     49.2425                 47.285000
# Austria                           NaN                 47.066667
# Belgium                       49.0840                 46.746667
# Brazil                        49.5650                       NaN
#
#                                amax                       \
# ...

# %%
df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.mean, np.max],
              margins=True).head()
# Out:
#                                mean                       \
# Rank_Level Fist Tier Top University Other Top University
# country
# Argentina                       NaN            44.672857
# Australia                   47.9425            44.645750
# Austria                         NaN            44.864286
# Belgium                     51.8750            45.081000
# Brazil                          NaN            44.499706
#
#                                                                             \
# Rank_Level Second Tier Top University Third Tier Top University        All
# country
# Argentina                         NaN                       NaN  44.672857
# Australia                     49.2425                 47.285000  45.825517
# Austria                           NaN                 47.066667  45.139583
# Belgium                       49.0840                 46.746667  47.011000
# Brazil                        49.5650                       NaN  44.781111
#
# ...

# %%
newdf=df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.mean, np.max],
              margins=True)
print(newdf.index)
print(newdf.columns)
# Out:
# Index(['Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Bulgaria',
#        'Canada', 'Chile', 'China', 'Colombia', 'Croatia', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Egypt', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Iran',
#        'Ireland', 'Israel', 'Italy', 'Japan', 'Lebanon', 'Lithuania',
#        'Malaysia', 'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Puerto Rico', 'Romania', 'Russia', 'Saudi Arabia',
#        'Serbia', 'Singapore', 'Slovak Republic', 'Slovenia', 'South Africa',
#        'South Korea', 'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand',
#        'Turkey', 'USA', 'Uganda', 'United Arab Emirates', 'United Kingdom',
#        'Uruguay', 'All'],
#       dtype='object', name='country')
# MultiIndex([('mean',   'Fist Tier Top University'),
#             ('mean',       'Other Top University'),
# ...

# %%
newdf['mean']['Fist Tier Top University'].head()
# Out:
# country
# Argentina        NaN
# Australia    47.9425
# Austria          NaN
# Belgium      51.8750
# Brazil           NaN
# Name: Fist Tier Top University, dtype: float64

# %%
newdf['mean']['Fist Tier Top University'].idxmax()
# Out:
# 'United Kingdom'

# %%
newdf = newdf.stack()
newdf.head()
# Out:
#                                            mean   amax
# country   Rank_Level
# Argentina Other Top University        44.672857  45.66
#           All                         44.672857  45.66
# Australia Fist Tier Top University    47.942500  51.61
#           Other Top University        44.645750  45.97
#           Second Tier Top University  49.242500  50.40

# %%
newdf.unstack().head()
# Out:
#                                mean                       \
# Rank_Level Fist Tier Top University Other Top University
# country
# All                       58.350675            44.738871
# Argentina                       NaN            44.672857
# Australia                 47.942500            44.645750
# Austria                         NaN            44.864286
# Belgium                   51.875000            45.081000
#
#                                                                             \
# Rank_Level Second Tier Top University Third Tier Top University        All
# country
# All                          49.06545                 46.843450  47.798395
# Argentina                         NaN                       NaN  44.672857
# Australia                    49.24250                 47.285000  45.825517
# Austria                           NaN                 47.066667  45.139583
# Belgium                      49.08400                 46.746667  47.011000
#
# ...

# %%
newdf.unstack().unstack().head()
# Out:
#       Rank_Level                country
# mean  Fist Tier Top University  All          58.350675
#                                 Argentina          NaN
#                                 Australia    47.942500
#                                 Austria            NaN
#                                 Belgium      51.875000
# dtype: float64

# %% [markdown]
# # Date/Time Functionality
