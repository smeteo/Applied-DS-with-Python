# %% [markdown]
# # Basic Statistical Testing

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv('grades.csv')
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# ...

# %%
df.shape
# Out:
# (2315, 13)

# %%
early_finishers = df[pd.to_datetime(df['assignment1_submission']) < '2016']
early_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 5  D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 8  C9D51293-BD58-F113-4167-A7C0BAFCB6E5          66.595568
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 4  2015-12-13 17:06:10.750000000          51.491040
# 5  2015-12-28 04:35:32.836000000          64.052550
# 8  2015-12-25 02:29:28.415000000          52.916454
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 4  2015-12-14 12:25:12.056000000          41.932832
# 5  2016-01-03 21:05:38.392000000          64.752550
# ...

# %%
early_finishers.shape
# Out:
# (1259, 13)

# %%
late_finishers = df[~df.index.isin(early_finishers.index)]
late_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 6  3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7  F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
# 9  E2C617C2-4654-622C-AB50-1550C4BE42A0          59.270882
#
#           assignment1_submission  assignment2_grade  \
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 6  2016-03-05 11:05:25.408000000          69.998995
# 7  2016-01-24 18:24:25.619000000          72.518481
# 9  2016-03-06 12:06:26.185000000          59.270882
#
#           assignment2_submission  assignment3_grade  \
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 6  2016-03-09 07:29:52.405000000          55.999196
# 7  2016-01-27 13:37:12.943000000          65.266633
# ...

# %%
late_finishers.shape
# Out:
# (1056, 13)

# %%
print(early_finishers['assignment1_grade'].mean())
print(late_finishers['assignment1_grade'].mean())
# Out:
# 74.94728457024303
# 74.0450648477065

# %%
from scipy.stats import ttest_ind
ttest_ind(early_finishers['assignment1_grade'], late_finishers['assignment1_grade'])
# Out:
# Ttest_indResult(statistic=1.322354085372139, pvalue=0.18618101101714551)

# %% [markdown]
# p value > 0.05 means we can't reject the null hypothesis.
# The two values are more or less same

# %%
print(ttest_ind(early_finishers['assignment2_grade'], late_finishers['assignment2_grade']))
print(ttest_ind(early_finishers['assignment3_grade'], late_finishers['assignment3_grade']))
print(ttest_ind(early_finishers['assignment4_grade'], late_finishers['assignment4_grade']))
print(ttest_ind(early_finishers['assignment5_grade'], late_finishers['assignment5_grade']))
print(ttest_ind(early_finishers['assignment6_grade'], late_finishers['assignment6_grade']))
# Out:
# Ttest_indResult(statistic=1.2514717608216366, pvalue=0.2108889627004424)
# Ttest_indResult(statistic=1.6133726558705392, pvalue=0.10679998102227865)
# Ttest_indResult(statistic=0.049671157386456125, pvalue=0.960388729789337)
# Ttest_indResult(statistic=-0.05279315545404755, pvalue=0.9579012739746492)
# Ttest_indResult(statistic=-0.11609743352612056, pvalue=0.9075854011989656)

# %% [markdown]
# In this data we don't have enough evidence to suggest the populations differ with respect to grade.

# %% [markdown]
# For example, for assignment 3, has a p-value around 0.1. This means that if we accepted a level of chance similarity of 11% this would have been considered statistically significant.

# %%
df1 = pd.DataFrame([np.random.random(100) for x in range(100)])
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.279357  0.205393  0.484014  0.592319  0.335373  0.581047  0.542868
# 1  0.310416  0.049158  0.389488  0.983091  0.023154  0.317498  0.142431
# 2  0.264343  0.276112  0.934804  0.390882  0.705271  0.156282  0.165541
# 3  0.023185  0.614521  0.356924  0.811578  0.085093  0.468698  0.000176
# 4  0.040340  0.114681  0.647076  0.989313  0.626447  0.705456  0.358810
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.399818  0.668057  0.325216  ...  0.522841  0.916860  0.627772  0.944481
# 1  0.302909  0.823972  0.918292  ...  0.759885  0.446645  0.107410  0.479511
# 2  0.372954  0.297634  0.553156  ...  0.548844  0.762023  0.791863  0.692536
# 3  0.856944  0.249119  0.064192  ...  0.903653  0.049095  0.333117  0.896856
# 4  0.816221  0.321079  0.117315  ...  0.538966  0.769190  0.008738  0.400968
#
#          94        95        96        97        98        99
# ...

# %%
df2 = pd.DataFrame([np.random.random(100) for x in range(100)])
df2.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.010256  0.617237  0.339640  0.985815  0.893692  0.756964  0.414092
# 1  0.227484  0.594979  0.925912  0.464461  0.336175  0.208856  0.130839
# 2  0.621986  0.900427  0.731554  0.037917  0.373878  0.744354  0.586340
# 3  0.276576  0.466926  0.683165  0.485992  0.282850  0.110540  0.873950
# 4  0.363758  0.113053  0.233412  0.020998  0.856615  0.255233  0.842616
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.451906  0.754411  0.560926  ...  0.049950  0.319177  0.972136  0.929199
# 1  0.622920  0.734119  0.141852  ...  0.934908  0.936824  0.449603  0.781812
# 2  0.972345  0.565400  0.381241  ...  0.079418  0.759284  0.261514  0.135146
# 3  0.530093  0.286444  0.837232  ...  0.155616  0.077655  0.767941  0.094150
# 4  0.710917  0.063242  0.478503  ...  0.480200  0.094484  0.355906  0.657343
#
#          94        95        96        97        98        99
# ...

# %% [markdown]
# Let's assign critical value 0.1, or alpha 10%

# %%
def test_columns(alpha=0.1):
    num_diff = 0
    for col in df1.columns:
        teststat, pval = ttest_ind(df1[col], df2[col])
        if pval <= alpha:
            print('Col {} is statistically significantly different at alpha={}, pval={}'.format(col, alpha, pval))
            num_diff += 1
    print('Total number different was {}, which is {}%'.format(num_diff, float(num_diff)/len(df1.columns)*100))

# %%
test_columns(0.1)
# Out:
# Col 21 is statistically significantly different at alpha=0.1, pval=0.05301571266522078
# Col 29 is statistically significantly different at alpha=0.1, pval=0.08208412509258363
# Col 31 is statistically significantly different at alpha=0.1, pval=0.09681041476590341
# Col 32 is statistically significantly different at alpha=0.1, pval=0.05603175270798616
# Col 35 is statistically significantly different at alpha=0.1, pval=0.02293502063443704
# Col 45 is statistically significantly different at alpha=0.1, pval=0.07106629902846491
# Col 48 is statistically significantly different at alpha=0.1, pval=0.06071678376986027
# Col 59 is statistically significantly different at alpha=0.1, pval=0.034400102859513046
# Col 64 is statistically significantly different at alpha=0.1, pval=0.005634756817987647
# Col 67 is statistically significantly different at alpha=0.1, pval=0.0923901259545156
# Col 83 is statistically significantly different at alpha=0.1, pval=0.0901517282156491
# ...

# %%
test_columns(0.05)
# Out:
# Col 35 is statistically significantly different at alpha=0.05, pval=0.02293502063443704
# Col 59 is statistically significantly different at alpha=0.05, pval=0.034400102859513046
# Col 64 is statistically significantly different at alpha=0.05, pval=0.005634756817987647
# Col 95 is statistically significantly different at alpha=0.05, pval=0.0025628211739714894
# Total number different was 4, which is 4.0%

# %%
df2 = pd.DataFrame([np.random.chisquare(df=1, size=100) for x in range(100)])
test_columns()
# Out:
# Col 0 is statistically significantly different at alpha=0.1, pval=3.064614255828415e-05
# Col 1 is statistically significantly different at alpha=0.1, pval=0.004994787626922517
# Col 2 is statistically significantly different at alpha=0.1, pval=0.0004262695552593834
# Col 3 is statistically significantly different at alpha=0.1, pval=9.326482076129827e-05
# Col 4 is statistically significantly different at alpha=0.1, pval=0.0003045131676673084
# Col 5 is statistically significantly different at alpha=0.1, pval=0.00010086668413415981
# Col 6 is statistically significantly different at alpha=0.1, pval=6.743466562750698e-05
# Col 7 is statistically significantly different at alpha=0.1, pval=0.00015520601337522225
# Col 8 is statistically significantly different at alpha=0.1, pval=0.0001260640155846951
# Col 9 is statistically significantly different at alpha=0.1, pval=5.543385126555806e-05
# Col 10 is statistically significantly different at alpha=0.1, pval=0.00013341544522275096
# ...
